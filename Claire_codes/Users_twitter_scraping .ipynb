# %%
import tweepy
import os
import re
import logging
import nltk
import string
import datetime
import pandas as pd
import numpy as np

# !pip install preprocessor

import preprocessor as p
from tweepy import OAuthHandler
from tweepy import API
from tweepy import Cursor
from nltk.corpus import stopwords
from textblob import TextBlob
# Out:
# Collecting preprocessor
#   Using cached https://files.pythonhosted.org/packages/96/ad/d9f4ffb9bb97d1cb5bcb876b7932571d4dbaa3eff1701ad45d367f0ea27b/preprocessor-1.1.3.tar.gz
# Installing collected packages: preprocessor
#   Running setup.py install for preprocessor ... error
#     Complete output from command /usr/bin/python2 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-z9CugS/preprocessor/setup.py';exec(compile(getattr(tokenize, 'open', open)(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" install --record /tmp/pip-EH_4VL-record/install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib
#     creating build/lib/preprocessor
#     copying preprocessor/__init__.py -> build/lib/preprocessor
#     running egg_info
#     writing preprocessor.egg-info/PKG-INFO
#     writing top-level names to preprocessor.egg-info/top_level.txt
#     writing dependency_links to preprocessor.egg-info/dependency_links.txt
#     warning: manifest_maker: standard file '-c' not found
#
#     reading manifest file 'preprocessor.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file 'preprocessor.egg-info/SOURCES.txt'
#     running build_scripts
#     creating build/scripts-2.7
#     copying and adjusting scripts/preprocessor -> build/scripts-2.7
#     changing mode of build/scripts-2.7/preprocessor from 644 to 755
#     running install_lib
#     creating /usr/lib/python2.7/site-packages/preprocessor
#     error: could not create '/usr/lib/python2.7/site-packages/preprocessor': Permission denied
#
#     ----------------------------------------
# Command "/usr/bin/python2 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-z9CugS/preprocessor/setup.py';exec(compile(getattr(tokenize, 'open', open)(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" install --record /tmp/pip-EH_4VL-record/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /tmp/pip-build-z9CugS/preprocessor/
# You are using pip version 8.1.2, however version 20.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
# from bs4 import BeautifulSoup
import pandas as pd
import os, sys

#import fire

import sys
import os
import json
import matplotlib.pyplot as plt
import re
import string

import matplotlib.dates as mdates
import seaborn as sns

# to view all columns
pd.set_option("display.max.columns", None)

import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API
from tweepy import Cursor
from datetime import datetime, date, time, timedelta
from collections import Counter
import sys

# !pip install preprocessor
import preprocessor as p
# Out:
# Collecting preprocessor
#   Using cached https://files.pythonhosted.org/packages/96/ad/d9f4ffb9bb97d1cb5bcb876b7932571d4dbaa3eff1701ad45d367f0ea27b/preprocessor-1.1.3.tar.gz
# Installing collected packages: preprocessor
#   Running setup.py install for preprocessor ... error
#     Complete output from command /usr/bin/python2 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-NVAji_/preprocessor/setup.py';exec(compile(getattr(tokenize, 'open', open)(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" install --record /tmp/pip-a8hydi-record/install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib
#     creating build/lib/preprocessor
#     copying preprocessor/__init__.py -> build/lib/preprocessor
#     running egg_info
#     writing preprocessor.egg-info/PKG-INFO
#     writing top-level names to preprocessor.egg-info/top_level.txt
#     writing dependency_links to preprocessor.egg-info/dependency_links.txt
#     warning: manifest_maker: standard file '-c' not found
#
#     reading manifest file 'preprocessor.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file 'preprocessor.egg-info/SOURCES.txt'
#     running build_scripts
#     creating build/scripts-2.7
#     copying and adjusting scripts/preprocessor -> build/scripts-2.7
#     changing mode of build/scripts-2.7/preprocessor from 644 to 755
#     running install_lib
#     creating /usr/lib/python2.7/site-packages/preprocessor
#     error: could not create '/usr/lib/python2.7/site-packages/preprocessor': Permission denied
#
#     ----------------------------------------
# Command "/usr/bin/python2 -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-NVAji_/preprocessor/setup.py';exec(compile(getattr(tokenize, 'open', open)(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" install --record /tmp/pip-a8hydi-record/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /tmp/pip-build-NVAji_/preprocessor/
# You are using pip version 8.1.2, however version 20.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
 #Variables that contains the user credentials to access Twitter API 
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret =''
sleep_on_rate_limit=False

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
auth_api = API(auth, wait_on_rate_limit=True)

# %%
hashtags=["#BreatheLife","#AirPollution","#airquality","#cleanair","#airpollution","#pollution","#hvac","#airpurifier" ,"#indoorairquality","#air","#climatechange","#indoorair","#environment" ,"#airconditioning","#heating" , "#freshair", "#airfilter","#ventilation","#airconditioner","#airqualityindex", "#pm2_5 ","#emissions","#natureishealing","#nature","#pollutionfree" ,"#wearethevirus",'AirPollution', 'Environment', 'Ozone Layer', 'Global Warming', 'Climate Change', 'Greenhouse Gases', 'Trees', 'Carbon',
        'Aerosals', 'Air', 'Save the planet', 'Factories', 'Hygroscopicity', 'Inversion', 'Sulfur', 'AIRS', 'ecosystem', 'Hydrochlorofluorocarbon',
        'hydrocarbon', 'TAC', 'zero', 'pollutant', '#air', '#pollution', '#airpollution', '#coal', '#particles', '#smog', '#cleanair',
       '#airqualityindex', '#climatechange', '#airquality', '#globalwarming', '#airpollutionawareness', '#airpollutioncontrol',
       '#CleanEnergy', '#saveearth']

geocodes=["6.48937,3.37709,500km","-33.99268,18.46654,500km","-26.22081,28.03239,500km","5.58445,-0.20514,500km","-1.27467,36.81178,500km","-4.04549,39.66644,500km","-1.95360,30.09186,500km","0.32400,32.58662,500km"]

names = []


names = []
for hashtag in hashtags:
    tweets = tweepy.Cursor(auth_api.search, q = hashtag ,geocode="0.0236,37.9062,530km").items(100000)
    users = []
    for status in tweets:
        name = status.user.screen_name
        t=status.text
        users.append(name)
    names.append(users)
screen_names = [y for x in names for y in x]
screen_names
# Out:
# ['IAQsusan',
#  'thetechsamya',
#  'BlueRiv88891964',
#  'SeeTheAirBot',
#  'elonfantommy',
#  'prothero_james',
#  'KlaudineWakasa',
#  'IAQsusan',
#  'innocentmaloba',
#  'thetechsamya',
#  'KingOwenR',
#  'Kampala4Climate',
#  'INFORSE_org',
#  'ESusWatch',
#  'Stephen91235019',
#  'DSS_Lab',
#  'h_doukas',
#  'KingOwenR',
#  'Kampala4Climate',
#  'AfricaSustain1',
#  'BlueRiv88891964',
#  'SeeTheAirBot',
#  'elonfantommy',
#  'prothero_james',
#  'KlaudineWakasa',
#  'IAQsusan',
#  'innocentmaloba',
#  'thetechsamya',
#  'KingOwenR',
#  'Kampala4Climate',
#  'solhog',
#  'RichardMunang',
#  'JimmyKarakaria',
#  'jovs_98',
#  'GLOBE_intl',
#  'SaniGamboUmar1',
#  'WasteOrCreate',
#  'NagudiIrene',
#  'DarioMelian',
#  'RSEOnline',
#  'RobertoValentUN',
#  'UNEP_NAmerica',
#  'svilardyq',
#  'SAMantilla1',
#  'SaleemulHuq',
#  'SaveWildlife12',
#  'kuepouo',
#  'dahirualiyu099',
#  'Shenever_knew',
#  'UrgeCollective',
#  'poornimathreya',
#  'YS4CIN',
#  'OlumideIDOWU',
#  'ClimateWed',
#  'CarolynFahm',
#  'ejvhattum',
#  'EU_ENV',
#  'TLC_CN',
#  'JTpaleo',
#  'UNEP',
#  'savinacp',
#  'MacondoChao',
#  'BVEdgerton',
#  'tuula',
#  'CUGHnews',
#  'jossbleriot',
#  'HollinsMargaret',
#  'GENetwork',
#  'rikusinervo',
#  'karllong',
#  'AlanaCraigen',
#  'CircularDsgNrb',
#  'SitraFund',
#  'andersen_inger',
#  'SaleemulHuq',
#  'RichardMunang',
#  'LisaMarieCricht',
#  'david_g_osborn',
#  'inspire_by',
#  'Kcic_Consulting',
#  'Jelaah_',
#  'Niyakin1',
#  'Kamaulisbeth',
#  'WamboiSeth',
#  'Laah117',
#  'N8Kwa',
#  'KomiRegina',
#  'AfricaSustain1',
#  'MathurFilipp',
#  'CodesmithSys',
#  'MusyokiGrace',
#  'estate_rex',
#  'artspace254',
#  'InnoDeckoks',
#  'EcoSanctify',
#  'agomagroupltd',
#  'MukiibiEmma2',
#  'KatanaHugo',
#  'OdzrtcySsIPXdoT',
#  'AStephen256',
#  'prisha_and',
#  'InfinityFurn_KE',
#  'PhilipAdruf',
#  'PeterMaswi',
#  'Newzug',
#  'Elizabe96273241',
#  'VilmaOnyamasi',
#  'EricDNjuguna',
#  'Roby41262525',
#  'TEES_Lab',
#  'OurFutureBot',
#  'Eric_Of_1691',
#  'ghanaleaksblog',
#  'RebekahGShirley',
#  'gingerhwells',
#  'Rosie_wearamask',
#  'Prarthana_AKKKS',
#  'Prarthana_AKKKS',
#  'Prarthana_AKKKS',
#  'jane__eden',
#  'Eco1stArt',
#  'massleona',
#  'PyeparFaisal',
#  'Eco1stArt',
#  'MChagara',
#  'MChagara',
#  'otangaevans',
#  'AGNESAfrika',
#  'CoffeeHoneyCoop',
#  'yvonnenyokabi',
#  'EnviroWild',
#  'minic_dk9',
#  'jane__eden',
#  'GreenSpacesKe',
#  'Makeadi30164733',
#  'Alfred996',
#  'OurFutureBot',
#  'KyotoRebellion',
#  'NorbertMusana',
#  'tzunami68',
#  'Inno_Vol_Ke',
#  'Inno_Vol_Ke',
#  'RichardMunang',
#  'RichardMunang',
#  'MMI_MMC',
#  'jane__eden',
#  'MDeFreese',
#  'emekeojukwu',
#  'LMupende',
#  'pfennigs',
#  'cngendahimana',
#  'Ict011',
#  'FTetero',
#  'Prarthana_AKKKS',
#  'Laah117',
#  'Laah117',
#  'Bill2001x',
#  'Nebby_99',
#  'jessicawins',
#  'emungai_m',
#  'UweWolef',
#  'malika_esther',
#  'Jmurugi3',
#  'pixiesio',
#  'bugfeedr',
#  'jane__eden',
#  'danyadabst',
#  'Monarijulius',
#  'KnudSknudsen',
#  'ConnieMckenney',
#  'PampuchRainer',
#  'AfricaSustain1',
#  'vanessa_vash',
#  'Trinity17431342',
#  'Frentecivico',
#  'JengelaChriss',
#  'OurFutureBot',
#  'XrLagos',
#  'ceackenya',
#  'JaphethOrieny',
#  'kiptoochemoiwo',
#  'icpac_igad',
#  'JPBucyensenge',
#  'GGGI_Rwanda',
#  'misflintch',
#  'realitycheque_k',
#  'AfricaSustain1',
#  'mbroecki',
#  'Gyan84s',
#  'jrobert_nl',
#  'jane__eden',
#  'AnimalNsw2015',
#  'besiandrew',
#  'allgringo',
#  'duncan_ndonga',
#  'AfricaSustain1',
#  'minic_dk9',
#  'felixpilipili',
#  'felixpilipili',
#  'Sayanta22578166',
#  'AfricaSustain1',
#  'jane__eden',
#  'MChagara',
#  'Kamaulisbeth',
#  'AfricaSustain1',
#  'WinnieCheche',
#  'BruceGathu',
#  'DayaniraCollins',
#  'DayaniraCollins',
#  'malungelo17',
#  'Roby41262525',
#  'minseo3647',
#  'GarlitzJenifer',
#  'ja8yum',
#  'MolinaElorza',
#  'MolinaElorza',
#  'Vevenock',
#  'Aramzede',
#  'ProMovement1',
#  'madlove_love',
#  'madlove_love',
#  'CouncilForYouth',
#  'MolinaElorza',
#  'blancasantos74',
#  'MolinaElorza',
#  'DannyWijnhoud',
#  'PSchinzler',
#  'riesenpanda',
#  'aluhoney',
#  'TPSpencer88',
#  'Nicholas_M_L',
#  'JosephusLudwig',
#  'madlove_love',
#  'JosephusLudwig',
#  'Phiristatic',
#  'recycledtwice',
#  'kiki_viola8',
#  'hackneywick',
#  'JosephusLudwig',
#  'Monarijulius',
#  'Monarijulius',
#  'Monarijulius',
#  'btkrth',
#  'Monarijulius',
#  'ChristianGilch',
#  'gvthillo',
#  'BeeNubian',
#  'Michael_Kunz',
#  'madlove_love',
#  'mkowa1',
#  'bobbolono',
#  'myenvironismine',
#  'FutureHamburg',
#  'GreenSpacesKe',
#  'Ezra_K_Yego',
#  'pulitzercenter',
#  'EzraHwang',
#  'DawnRoseTurner',
#  'ChristophBeisl1',
#  'ngwochela',
#  'Uptoten22',
#  'krishve79227141',
#  'WFooled',
#  'Uptoten22',
#  'Aiko96788255',
#  'Uptoten22',
#  'mrigankasinha',
#  'sergiovarmo',
#  'LittleBirdSteph',
#  'Charles41784654',
#  'Ruthnan5',
#  'RobindosBosque2',
#  'redphael',
#  'ImaitaRaphael',
#  'redmayne_robert',
#  'Siacu_ASBL',
#  'levandematerial',
#  'rohit_mulay',
#  'onjolo_kenya',
#  'onjolo_kenya',
#  'MJosling53',
#  'MJosling53',
#  'princyammu27',
#  'Gyan84s',
#  'PhillylovesWHC',
#  'akshay_sonawala',
#  'Elizabe96273241',
#  'juristadofuturo',
#  'SMuhuha',
#  'RobindosBosque2',
#  'GloballyKenyan',
#  'mdt4129',
#  'krosenlund_com',
#  'sm_kagenyi_PhD',
#  'KemuntokK',
#  'redmayne_robert',
#  'hiramkush',
#  'WildForLifeNow',
#  'apondi_edith',
#  'imagine_garden',
#  'picogiovanni',
#  'NatureTourism1',
#  'NatureTourism1',
#  'Elijahfeed',
#  'MumbaMusondam',
#  'spark_inside_me',
#  'jane__eden',
#  'JuluOkadia',
#  'RichardMunang',
#  'RhinoArk',
#  'ebafosaa',
#  'Shubham59781984',
#  'econoduu',
#  'Tcaddy5',
#  'AnnieWahlund',
#  'Siacu_ASBL',
#  'CSpechtl',
#  'RMatter2018',
#  'Jelaah_',
#  'AloyceUrassa',
#  'jane__eden',
#  'ManiaReckless',
#  'gmc004',
#  'didi_stanley',
#  'OurFutureBot',
#  'fester_thomas',
#  'anitasoina',
#  'redmayne_robert',
#  'elxdix',
#  'onjolo_kenya',
#  'onyango_victor',
#  'KVenator',
#  'onjolo_kenya',
#  'Roby41262525',
#  'joe_mutahi',
#  'WinnieCheche',
#  'KNieuwhuis',
#  'madlove_love',
#  'OreganoTheOnly',
#  'AntTony64846932',
#  'JoeKaiyahe',
#  'MumbaMusondam',
#  'muinde_muthengi',
#  'muinde_muthengi',
#  'muinde_muthengi',
#  'dorobuk',
#  'patriciakombo',
#  'laplapv3',
#  'Nandini72113762',
#  'Sydneyngobi',
#  'KIVUNature',
#  'MadiAfrica',
#  'RMBlaber56',
#  'KuttuRekha',
#  'jane__eden',
#  'WinnieCheche',
#  'AntTony64846932',
#  'KVenator',
#  'livrollinger',
#  'patriciakombo',
#  'susanonyango',
#  'realitycheque_k',
#  'Ecoxplore18',
#  'AfricaSustain1',
#  'LabradorLandPr1',
#  'jane__eden',
#  'AABookstore',
#  'LlewelynPritch',
#  'Sankorie',
#  'AWFCEO',
#  'AWFCEO',
#  'UnitedForClima1',
#  'Favourfavor2',
#  'patriciakombo',
#  'annikam93',
#  'hiramkush',
#  'NETWASU',
#  'madlove_love',
#  'hiramkush',
#  'hiramkush',
#  'jane__eden',
#  'marianatrobosky',
#  'MacKiyimba',
#  'EUinUG',
#  'ClimateChangeE3',
#  'ADCinUganda',
#  'Jelaah_',
#  'BujariRev',
#  'LtdWoodfarm',
#  'mulunga_alukwe',
#  'mulunga_alukwe',
#  'AfricaSustain1',
#  'patinaaiosim',
#  'AfricaSustain1',
#  'hopienaticsvhon',
#  'unhabitatyouth',
#  'ILEKTRAKOUTOUKI',
#  'LOVE2UNIQUE',
#  'Nandini72113762',
#  'KVenator',
#  'WinnieCheche',
#  'WinnieCheche',
#  'MazingiraI',
#  'AloyceUrassa',
#  'PostonSunday1',
#  'dedan1alien',
#  'ksamy2678',
#  'ReefLife911',
#  'VarshneyAnita',
#  'SaleemulHuq',
#  'Mpassy_JR',
#  'RAMONDOMINGUEZG',
#  'redmayne_robert',
#  'Dibordz',
#  'odoidaniel1',
#  'JaydeLovell',
#  'nomoreslaves',
#  'prateek03387700',
#  'Milanowekpet',
#  'birthdays_for',
#  'TravelNasi',
#  'IsaacRwanda',
#  '_monicah_shiku',
#  'jane__eden',
#  'Ansh07_',
#  'Sayanta22578166',
#  'Prarthana_AKKKS',
#  'bar_zie',
#  '_RoosSingh',
#  'jyotsna2964',
#  'VisualPersist',
#  'gasparepolizzi9',
#  'jane__eden',
#  'UNESCOWWAP',
#  'LtdWoodfarm',
#  'Eylem4561',
#  'SudarshanAshok',
#  'commupolicing',
#  'ChrisBrey1',
#  'ImaitaRaphael',
#  'TmymonsoonH',
#  'WWFDRC',
#  'consciousaya',
#  'jane__eden',
#  'GardensSerene',
#  'PHIAtweets',
#  'gbarbieb',
#  'ZoilaCr72741419',
#  'SARAKARNTHI1',
#  'Nancykaushal2',
#  'topsy_tee',
#  'Gyan84s',
#  'ThisIsGatheru',
#  'hughmanatee01',
#  'SonjaLehmann5',
#  'PiaAngelesBarr1',
#  'UNESCO',
#  'jane__eden',
#  'Ibrahim_Okedara',
#  'evenspl',
#  'UNEP',
#  'JaphethOrieny',
#  'RotaractLimuru',
#  'OukoEvone',
#  'jane__eden',
#  'Costappelle14',
#  'WWFDRC',
#  'curriealder',
#  'KappelleMaarten',
#  'mauolivares',
#  'sophiasmonde',
#  'MigrMatters',
#  'KalukiPaul',
#  'Kamaulisbeth',
#  'LouisaWet',
#  'sm_kagenyi_PhD',
#  'kanjoo',
#  'jane__eden',
#  'BHO1996',
#  'BusinessNisq',
#  'NathanNgumi',
#  'ImeldaNasubo',
#  'jane__eden',
#  'EdenCampsClubs',
#  'risivonne',
#  'ashleykitisya',
#  'sm_kagenyi_PhD',
#  'MChagara',
#  'Nytil2',
#  'diangaronald',
#  'jane__eden',
#  'OchiengAgong',
#  'AfricaSustain1',
#  'kamene_muema',
#  'FAOKenya',
#  'RichardMunang',
#  'RichardMunang',
#  'Kiprono_Lagatt',
#  'Eco1stArt',
#  'freddybobjones',
#  'jane__eden',
#  'jane__eden',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'inspire_by',
#  'Roby41262525',
#  'isibams',
#  'Ambani_Ambani',
#  'jane__eden',
#  'MumoPascal',
#  'BM_Isaiah',
#  'RichardMunang',
#  'jane__eden',
#  'RMalango2015',
#  'CazeauHue',
#  'LtdWoodfarm',
#  'RichardMunang',
#  'mytreeUganda',
#  'Eco1stArt',
#  'jane__eden',
#  'KuttuRekha',
#  'freddybobjones',
#  'Claudia_0791',
#  'DenisNishant',
#  'SDGs4Pakistan',
#  'LardasL',
#  'Uptoten22',
#  'anitasoina',
#  'imagine_garden',
#  'Eco1stArt',
#  'ImaitaRaphael',
#  'toitacai',
#  'jane__eden',
#  'brenda_ngoya',
#  'DawnRoseTurner',
#  'LindaAgnew8',
#  'imagine_garden',
#  'XRNamur',
#  'PlanetRetweets',
#  'UNHABITAT',
#  'MarcoTeixeiraUN',
#  'JoinIsmail',
#  'Kamaulisbeth',
#  'KARIUKING',
#  'KARIUKING',
#  'KARIUKING',
#  'joneishere',
#  'akshay_sonawala',
#  'RoplingReinhard',
#  'equalitynow_ug',
#  'KemuntokK',
#  'Nitrogl41152579',
#  'JOEMusa88128543',
#  'Jansuse',
#  'Tachonisfinest',
#  'LuQiCENSORED',
#  'Dr_AO_Bouh',
#  'Piros12',
#  'corporate_irish',
#  'UlrikeHeiss',
#  'jane__eden',
#  'MtlSeb',
#  'onjolo_kenya',
#  'onjolo_kenya',
#  'richardmuganzi',
#  'leonard_ondigo',
#  'hiramkush',
#  'hiramkush',
#  'jane__eden',
#  'hiramkush',
#  'hiramkush',
#  'hiramkush',
#  'Sankorie',
#  'jane__eden',
#  'patinaaiosim',
#  'jane__eden',
#  'monsodana',
#  'appolo_kevin',
#  'WakoJoel',
#  'adrianasah',
#  'Rhino_Charge',
#  'AQ61',
#  'jane__eden',
#  'Newzug',
#  'fsagwe',
#  'AfricaSustain1',
#  'jane__eden',
#  'prudencelihabi1',
#  'Green_Thingz',
#  'realronlocke',
#  'Roby41262525',
#  'EdgarOjeda17',
#  'jamokibaki',
#  'NjeriMaria2',
#  'NathanNgumi',
#  'IamPearlita',
#  'jane__eden',
#  'hiramkush',
#  'hiramkush',
#  'DeoWalusimbi',
#  'bot_africana',
#  'ADCinUganda',
#  'hiramkush',
#  'kimaniwanjogu',
#  'hiramkush',
#  'WMutunga',
#  'WillKnocker',
#  'Newzug',
#  'Ruthjelagat13',
#  'equalitynow_ug',
#  'kattludd',
#  'Tanntric',
#  'Andromake000',
#  'joe_mutahi',
#  'FaithThimba',
#  'VeraBaboun',
#  'bangirac',
#  'brade1991',
#  'jane__eden',
#  'DeoWalusimbi',
#  'chemutaipraisy',
#  'NelsonGichuki1',
#  'Charlesigaa',
#  'Latza70',
#  'jane__eden',
#  'jane__eden',
#  'jane__eden',
#  'AllinforClimate',
#  'princepapa1',
#  'princepapa1',
#  'princepapa1',
#  'lynn_kandie',
#  'OmarElmawi',
#  'OmarElmawi',
#  'jnharkeraus',
#  'GabMercurio',
#  'deCOALonize',
#  'deCOALonize',
#  'gp_kenyagroup',
#  'jane__eden',
#  'jane__eden',
#  'gp_kenyagroup',
#  'deCOALonize',
#  'deCOALonize',
#  'WorldEnergyDay',
#  'deCOALonize',
#  'deCOALonize',
#  'deCOALonize',
#  'deCOALonize',
#  'Charlesigaa',
#  'poshgero',
#  'Charlesigaa',
#  'Wanja_Kiongo',
#  'TheMboya',
#  'TheMboya',
#  'nickischenker',
#  'Kl_Stone',
#  'MaanKeshav',
#  'TheMboya',
#  'patinaaiosim',
#  'TheMboya',
#  'jyoticsharma',
#  'PA_EastAfrica',
#  'N8Kwa',
#  'Uptoten22',
#  'kean_network',
#  'niyi7busari',
#  'SMuhuha',
#  'masterprogram1',
#  'RabinowitzLee',
#  'GadgetKidKe',
#  'ReliveAfrica',
#  'aribett55',
#  'BlueForrestKe',
#  'MutaveNelly',
#  'LlewKenya',
#  'Clean_pea',
#  'ahumanofearth',
#  'anujabali',
#  'RMBlaber56',
#  'franciskykes',
#  'Beatric54184322',
#  'khsad67',
#  'Nunez200',
#  'marcus_brand',
#  'ilmaormaa',
#  'mslindblom',
#  'j9IM67OZnObLMM8',
#  'redmayne_robert',
#  'wastefighter',
#  'vrosauer',
#  'WeManifestPeace',
#  'Aleckeei',
#  'Aleckeei',
#  'Colne_Pt_Birder',
#  'RevBradshaw',
#  'Ash75566405',
#  'ppptec',
#  'larsinge_sand',
#  'Ash75566405',
#  'viclit445',
#  'dalitmatterROI',
#  'Roby41262525',
#  'HartmutVoigt',
#  'NoahsArkCrew',
#  'AlbertFlorian4',
#  'Sriyalama',
#  'Roby41262525',
#  'ethelnandhego1',
#  'RobHoenen',
#  'DNotacat',
#  'brothadestin',
#  'muinde_muthengi',
#  'LiamNixon13',
#  'NAFOPHANU',
#  'Kamaulisbeth',
#  'Kamaulisbeth',
#  'Kamaulisbeth',
#  'AdrianeVillano',
#  'doikea',
#  'NiringiyeDeus',
#  'krosenlund_com',
#  'TheMboya',
#  'jrobert_nl',
#  'jrobert_nl',
#  'phebekiruba',
#  'btkrth',
#  'onyangom14',
#  'peetersfrank2',
#  'AfricaSustain1',
#  'CASAESOL',
#  'Onesmus_Musyoki',
#  'LeanneStewart',
#  'FlavThunbWolf',
#  'jane__eden',
#  'patriciakombo',
#  'TheMboya',
#  'HartmutVoigt',
#  'TheMboya',
#  'Sir_Psam',
#  'TheMboya',
#  'NcDitz',
#  'YS4CIN',
#  'matsxekberg',
#  'GrenAja',
#  'RichardMunang',
#  'RichardMunang',
#  'artyghok21',
#  'jan_snauwaert',
#  'YekaWilliam',
#  'kayemba_b',
#  'AfricaSustain1',
#  '_TreeSt',
#  'BlauerEisvogel',
#  'jane__eden',
#  'GathuMaurice',
#  'SchoolCO2lution',
#  'RMBlaber56',
#  'tree_adoptionug',
#  'AfricaSustain1',
#  'BEN44646755',
#  'masterprogram1',
#  'priyagujadhur',
#  'TiedeDth',
#  'zaby900',
#  'trishcahill',
#  'laplapv3',
#  'Ronnie_Ug',
#  'solidarityandlo',
#  'gijnAfrica',
#  'vetcov19',
#  'XRShrewsbury',
#  'EUinUG',
#  'DaloumCd',
#  'drtobbe',
#  'mwatondo',
#  'EUinUG',
#  'pallastina7',
#  'ChaTucker0',
#  'Newzug',
#  'Emergency4all',
#  '_editor81',
#  'Gbemmienaike',
#  'GichApollo',
#  'mmbrown2000',
#  'Roby41262525',
#  'Grupo_DDP',
#  'Kiprono_Lagatt',
#  'Eco1stArt',
#  'MamlakaFoods',
#  'danny_where',
#  'AjayKum87859274',
#  'K1LL3RQU33NB0SS',
#  'SDG2030',
#  'unplasticday',
#  'umitotsuki',
#  'MalissaYangMD',
#  'toshi_nekoinu',
#  'HanserikErik',
#  'KellyTurberfie1',
#  'kingfowlness',
#  'SafikSsenyonga',
#  'jjjjjjj1943',
#  'tscottjones',
#  'OdopeCan',
#  'GoodAppleClub',
#  'Melica_N',
#  'dear_Bunni',
#  'SvenFolkesson',
#  'amanon99',
#  'jmarinezmaya',
#  'jennyrogers_ray',
#  'linsocw',
#  'LittleB47207665',
#  'YukoIshizuka1',
#  'vivian_almas',
#  'MaddyLina25',
#  'marionprof',
#  'blackla62213186',
#  'MarkOls60595347',
#  'hart35846751',
#  'Hefesitas',
#  'morvabowman',
#  'alexkimeu0',
#  'living_sweden',
#  'CornelsSelke',
#  'OnduuAkinyi',
#  'OurJourney_Life',
#  'Muhatia_Benjy',
#  'daniel_scholler',
#  'Cinnamongirl309',
#  'Bobshabby2',
#  'AnsisEgle',
#  'MC4AVAHYL',
#  'NakabuyeHildaF',
#  'TomArchibald',
#  'gpmartinP',
#  'JulioangelE',
#  'SabinaSchmidt20',
#  'tariro_de',
#  'linda_lindylou',
#  'EmilBergholtz',
#  'Lizsilk4',
#  'IamAnnaRosalie',
#  'AfepDiaz13',
#  'solhog',
#  'tsvenson',
#  'KerstenLewerenz',
#  'BlokeinEngland',
#  'WendowsLane',
#  'york0982',
#  'WilliamDGoodman',
#  'SuryaSwaran',
#  'setyourmindfree',
#  'EnviroWild',
#  'hazelleenut',
#  'Melany_MV12',
#  'miracleboy_1997',
#  'katar87',
#  'suki3hunna',
#  'macooke1',
#  'Andrew88820142',
#  'CitizenoftheWo4',
#  'joylowell',
#  'NSinayobye',
#  'chicating',
#  'aanthanur',
#  'ruby_ingle',
#  'stangunawan',
#  'LetsRoc137',
#  'eguerre4',
#  'Beaurive',
#  'Lapus24',
#  'KbLeecaster',
#  'adpucci',
#  'OogyCoyote',
#  'lilith2u',
#  'MaximilianVict4',
#  'AnnManes2',
#  'luyorc4',
#  'whoawmina',
#  'brijeshrai',
#  'gracchus56',
#  'juliaandersson_',
#  'petercscott',
#  'EdithBosquetti',
#  'Superabderit',
#  'Jonah24899753',
#  'danlandgre',
#  'JannaDemm',
#  'RoyalSelkie',
#  '3333333333am',
#  'jane__eden',
#  'jane__eden',
#  'jane__eden',
#  'JHilde9',
#  'VilmNovohradsk1',
#  'GretaThunberg',
#  'EroNesh',
#  'MugalulaPius',
#  'Fridays4FutureU',
#  'SadrachNirere',
#  'SwedeninUG',
#  'ImaitaRaphael',
#  'jane__eden',
#  'Roby41262525',
#  'KingOwenR',
#  'Sankorie',
#  'patinaaiosim',
#  'LtdWoodfarm',
#  'yaramfall58',
#  'WinnieCheche',
#  'Ckibii',
#  'MohamedFall',
#  'Kamaulisbeth',
#  'Kamaulisbeth',
#  'jane__eden',
#  'Kamaulisbeth',
#  'Laah117',
#  'Kampala4Climate',
#  'Laah117',
#  'Kafi001',
#  'ClimateChangeE3',
#  'AfricaSustain1',
#  'Sandra_Suubi',
#  'MillerOval',
#  'doraakolo',
#  'aamdihun',
#  'OurFutureBot',
#  'KakushaVenecia',
#  'kijomba1',
#  'AfricaSustain1',
#  'grayc',
#  'kayijamahe',
#  'icpac_igad',
#  'icpac_igad',
#  'ochiengmoses111',
#  'MurayaKevin2',
#  'RotaryGachie',
#  'AECFAfrica',
#  'MathurFilipp',
#  'angwenyiryzer',
#  'sm_kagenyi_PhD',
#  'AfricaSustain1',
#  'RichardMunang',
#  'chimz_green',
#  'jane__eden',
#  'Newzug',
#  'Eco1stArt',
#  'kinyua_wambu',
#  'PSAgriculture',
#  'ceprodilic',
#  'RGabdho',
#  '_monicah_shiku',
#  'RGabdho',
#  'UNDP_GCRED',
#  'Ochweri',
#  'Delinah_Mijide',
#  'EnviroWild',
#  'DotGarbage',
#  'Eco1stArt',
#  'Ckibii',
#  'paulaachi1',
#  'Stephen91235019',
#  'RotaryGachie',
#  'Prarthana_AKKKS',
#  'machtm',
#  'GardenofhopeFdn',
#  'MaigaMark',
#  'RotaractKarura',
#  'leemajid',
#  'icpac_igad',
#  'WildnowF',
#  'BazWaiswa',
#  'besiandrew',
#  'AfricaSustain1',
#  'BartNorbruis',
#  'SimbaMedicare',
#  'Faazati',
#  'stucable',
#  'Health_NewsUg',
#  'KNieuwhuis',
#  'africawoodgrow',
#  'Kamaulisbeth',
#  'AloyceUrassa',
#  'MugutaDennis',
#  'OurFutureBot',
#  'EmacarFrank',
#  'mulunga_alukwe',
#  'mulunga_alukwe',
#  'mulunga_alukwe',
#  'AfricaSustain1',
#  'Lina24588557',
#  'JonsMindy',
#  ...]

# %%
screen_names
df = pd.DataFrame(screen_names)
df.to_csv("handles_100000.csv")
